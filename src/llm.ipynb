# %%
# %load_ext autoreload
# %autoreload 2

# %%
from llm import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_489743/2057748149.py in <module>
# ----> 1 from llm import *
#
# ~/cs308/project/PKU_Project/src/llm.py in <module>
#       2 import os
#       3 import json
# ----> 4 from openai import OpenAI
#       5 from init import analyze_images
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'openai'

# %%
dir = '../testset'
analysis_results = load_analysis_results(dir)
user_description = "He is middle aged"
res = match_images_with_description(analysis_results,user_description)
print(res)
# Out:
# [('img34.jpg', 90.0), ('img33.jpg', 10.0), ('img37.jpg', 10.0)]

# %%
display_images(dir,res)
